# %%
import pandas as pd
import numpy as np


from sklearn.linear_model import LassoLars
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('std_df_full.csv', index_col = 0)

# %%
y = df.pop('value')
x = df

# Splitting the data into training and testing datasets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 42)

# %%
# Creating and fitting the regressor
model_lars = LassoLars(alpha = 0.1)
model_lars.fit(x_train, y_train)
 
 
# Evaluating model
predict_value = model_lars.predict(x_test) 
print(f"R-squared Score of the test dataset : {r2_score(y_test, predict_value)}")
# Out:
# R-squared Score of the test dataset : 0.9603186675626085

# %%
# Creating and fitting the regressor
model_lars2 = LassoLars(alpha = 0.2)
model_lars2.fit(x_train, y_train)
 
 
# Evaluating model
predict_value2 = model_lars2.predict(x_test) 
print(f"R-squared Score of the test dataset : {r2_score(y_test, predict_value2)}")
# Out:
# R-squared Score of the test dataset : 0.8495130924376312

# %%
# Creating and fitting the regressor
model_lars3 = LassoLars(alpha = 0.5)
model_lars3.fit(x_train, y_train)
 
 
# Evaluating model
predict_value3 = model_lars3.predict(x_test) 
print(f"R-squared Score of the test dataset : {r2_score(y_test, predict_value3)}")
# Out:
# R-squared Score of the test dataset : 0.08604830046459266

# %%
# Plotting the predicted values against the actual values
import seaborn as sb
from matplotlib import pyplot as plt

sb.distplot(predict_value, hist = False, color = 'r', label = 'Predicted')
sb.distplot(y_test, hist = False, color = 'b', label = 'Actual')
plt.title('Actual vs Predicted', fontsize = 10)
plt.xlabel('Values', fontsize = 10)
plt.ylabel('Frequency', fontsize = 10)
plt.legend(loc = 'upper left', fontsize = 10)
